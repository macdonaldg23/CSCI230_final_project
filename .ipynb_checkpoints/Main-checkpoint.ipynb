# %%
from eda import *
from rfc import *
# Out:
# ==================Exploratory Data Analysis==================
#
# Importing the dataset...
#           Attr1    Attr2     Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0      0.824618  2.27462  0.869570   7.1011 -122.5510  2.311830  1.021850
# 1      0.251801  2.50297  1.443380   8.2638   -6.6983  0.000607  0.338228
# 2      0.707843  1.67865  2.526030  14.7833  401.2407  0.542450  0.881417
# 3      0.379978  2.71058  1.361734   8.7516  -83.2420  1.150333  0.449089
# 4      0.399152  2.65700  1.227570   7.7936  -82.1588  0.375220  0.478330
# ...         ...      ...       ...      ...       ...       ...       ...
# 10498       NaN      NaN       NaN      NaN       NaN       NaN       NaN
# 10499       NaN      NaN       NaN      NaN       NaN       NaN       NaN
# 10500       NaN      NaN       NaN      NaN       NaN       NaN       NaN
# 10501       NaN      NaN       NaN      NaN       NaN       NaN       NaN
# ...

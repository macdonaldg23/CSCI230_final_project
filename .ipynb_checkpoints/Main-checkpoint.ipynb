# %%
from eda import *
from rfc import *
# Out:
# ====================================== Beginning Decision Tree Classifier ============================================
#
#
#
#
# --------------------------- Addressing over and underfitting with validation curves ------------------------
# /Users/warrenseeds/miniforge3/envs/mlp/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/warrenseeds/miniforge3/envs/mlp/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/warrenseeds/miniforge3/envs/mlp/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...
